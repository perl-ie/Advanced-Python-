# %% [markdown]
# <a href="https://colab.research.google.com/github/perl-ie/Advanced-Python-/blob/main/web_scraping_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://btech-data-analytics.github.io/bridgerland-technical-college/employees_3.html').text

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
soup.find('table').find_all('tr', class_='employee')[0].find_all('td')[1].text
# Out:
# 'John Doe'

# %%
name = []
id = []
age = []

for employee in soup.find('table').find_all('tr', class_='employee'):
  id.append(employee.find_all('td')[0].text)
  name.append(employee.find_all('td')[1].text)
  age.append(employee.find_all('td')[2].text)

# %%
name
# Out:
# ['John Doe',
#  'Jane Smith',
#  'Robert Johnson',
#  'Mary Johnson',
#  'Michael Brown',
#  'Susan Davis',
#  'David Wilson',
#  'Linda Miller']

# %%
id
# Out:
# ['101', '102', '103', '104', '105', '106', '107', '108']

# %%
age
# Out:
# ['28', '32', '24', '29', '35', '27', '31', '33']

# %%
df = pd.DataFrame({
    'id': id,
    'name': name,
    'age': age
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8 non-null      object
#  1   name    8 non-null      object
#  2   age     8 non-null      object
# dtypes: object(3)
# memory usage: 324.0+ bytes

# %%
import pandas as pd

# %%
url = "https://btech-data-analytics.github.io/bridgerland-technical-college/employees_3.html"

# %%
df = pd.read_html(url)[0]

# %%
#1
print(df["Age"].mean())
# Out:
# 29.875

# %%
#2
print(round(df["Age"].std(), 2))
# Out:
# 3.56
